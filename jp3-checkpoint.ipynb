# %% [markdown]
# # Beta Data Anaysis

# %% [markdown]
# We have been working to create a number of queries that describe the contents in the existing enriched-data collection. This notebook can be configured to point to any of the 3 environments (Live, Integration, DevQA).

# %%
# Related page
# http://confluence.epnet.com/display/ART/Spike+-+Date+field%28s%29+analyses+by+content+type+in+Raw-Meta

# Start of the script
import pandas as pd
import pymongo
from pymongo import MongoClient
import time
import datetime



env = input("Please Select an Environment D,I or L: ")
if env == "D":
    mng_svr = '10.25.216.142'
    mng_port = 27017
    mng_user = 'readOnlyUser'
    mng_pwd = 'uk53r8gb22zq76qb'
    mng_conn_string = mng_svr,mng_port,mng_user,mng_pwd
    print("Configuring for DevQA")
elif env == "I":
    mng_svr = '10.25.155.11'
    mng_port = 27017
    mng_user = 'readOnlyUser'
    mng_pwd = 'uk53r8gb22zq76qb'
    mng_conn_string = mng_svr,mng_port,mng_user,mng_pwd
    print("Configuring for Integration")
elif env == "L":
    mng_svr = '10.26.152.183'
    mng_port = 27017
    mng_user = 'readOnlyUser'
    mng_pwd = 'uk53r8gb22zq76qb'
    mng_conn_string = mng_svr,mng_port,mng_user,mng_pwd
    print("Configuring for Live")
else:
     print("No usable environment selected")
     exit()


#mng_conn_string = (mng_svr,mng_port,mng_user,mng_pwd)
print (mng_conn_string)


client = MongoClient (mng_svr,mng_port,username = mng_user, password = mng_pwd)
db = client.documents
collection = db['enriched-meta']



start = time.time()
print ("Connection complete")





#=====================================================
#Determine the content types in the collection

#Dist = collection.aggregate([{"$group" : {"_id" : {"type" : "content-type"}, "total" : {"$sum" : 1} }},{"$sort": {"total": -1}}])
#df = pd.DataFrame(list(Dist))



#Dist = collection.aggregate([{"$group" : {"_id" : {"vertical" : "$header.content-verticals"}, "total" : {"$sum" : 1} }},{"$sort": {"total": -1}}])
#df = pd.DataFrame(list(Dist))
#data = pd.DataFrame(list(collection.find().limit(1000)))

# End of the script
# Out:
# Please Select an Environment D,I or L: L
# Configuring for Live
# ('10.26.152.183', 27017, 'readOnlyUser', 'uk53r8gb22zq76qb')
# Connection complete

# %%
print("Initial analysis starting")
allRecords = collection.count_documents({})
print("Number of documents: ", allRecords)
mfsRecords = collection.count_documents({"header.content-type":"sch"})
print("Number of MFS documents: ", mfsRecords)
imgRecords = collection.count_documents({"header.content-type":"imh"})
print("Number of Image documents: ", imgRecords)
ersRecords = collection.count_documents({"header.content-type":"ers"})
print("Number of ERS documents: ", ersRecords)
print("Initial analysis complete")
# Out:
# Initial analysis starting
# Number of documents:  1157160
# Number of MFS documents:  810936
# Number of Image documents:  277109
# Number of ERS documents:  69115
# Initial analysis complete

# %%
#Determine the content types in the collection
print ("Content Type Analysis starting")
Dist = collection.aggregate([{"$group" : {"_id" : {"type" : "$header.content-type"}, "total" : {"$sum" : 1} }},{"$sort": {"total": -1}}])
df = pd.DataFrame(list(Dist))
df["Perc"] = df['total'] / allRecords * 100

print ("Content Type Analysis complete")
# Out:
# Content Type Analysis starting
# Content Type Analysis complete

# %%
df.round(2)
# Out:
#                  _id   total   Perc
# 0  {'type': ['sch']}  810936  70.08
# 1  {'type': ['imh']}  277109  23.95
# 2  {'type': ['ers']}   69115   5.97

# %% [markdown]
# Date Analysis; We will look at the prevalance of string dates in MFS fields.

# %%
print("Date analysis starting")
mfsRecords_w_date = collection.count_documents({
    '$and' : [{ "header.content-type" :  "sch"},
            {"date.string-date" :  {"$exists" : True}}]
})

Dist = collection.aggregate([{"$match" : { "header.content-type":"sch"}}, {"$group" : { "_id" : "$date.string-date", "total" : {"$sum" : 1} }}, {"$sort": {"total":-1}}])
df = pd.DataFrame(list(Dist))
print("MFSDocuments_W_Date: ", mfsRecords_w_date )
print("Percentage of MFS documents with a String Date: ", mfsRecords_w_date/mfsRecords * 100)
print("Date analysis complete")
# Out:
# Date analysis starting
# MFSDocuments_W_Date:  810936
# Percentage of MFS documents with a String Date:  100.0
# Date analysis complete

# %%
df
# Out:
#                                           _id  total
# 0                 [Oct2017, 1506816000000000]  33490
# 1                    [2005, 1104537600000000]   4355
# 2                [8/1/2017, 1501545600000000]   2294
# 3                    [2003, 1041379200000000]   1934
# 4                 [Oct2005, 1128124800000000]   1650
# 5                [3/1/2006, 1141171200000000]   1620
# 6                 [Sep2005, 1125532800000000]   1590
# 7                 [Feb2005, 1107216000000000]   1583
# 8                 [Apr2005, 1112313600000000]   1577
# 9                 [Mar2005, 1109635200000000]   1554
# 10                [Oct2007, 1191196800000000]   1540
# 11                [Mar2006, 1141171200000000]   1474
# 12                [Mar2008, 1204329600000000]   1470
# 13                [Oct2004, 1096588800000000]   1462
# 14                [Sep2008, 1220227200000000]   1458
# 15                [Sep2007, 1188604800000000]   1437
# 16                [Oct2008, 1222819200000000]   1424
# 17                [Sep2006, 1157068800000000]   1422
# 18                [Jun2005, 1117584000000000]   1404
# 19                [Jan2005, 1104537600000000]   1394
# 20                [Mar2007, 1172707200000000]   1380
# 21                [Sep2004, 1093996800000000]   1373
# 22                [Jun2008, 1212278400000000]   1365
# 23                [Dec2005, 1133395200000000]   1363
# 24                [Mar2009, 1235865600000000]   1354
# 25                [May2005, 1114905600000000]   1347
# 26                [Apr2006, 1143849600000000]   1339
# 27                [Apr2008, 1207008000000000]   1322
# 28                [Oct2012, 1349049600000000]   1316
# 29                [Apr2012, 1333238400000000]   1316
# ...                                       ...    ...
# 13689               [5/3/96, 831081600000000]      1
# 13690            [10/1/1994, 780969600000000]      1
# 13691            [12/5/1997, 881280000000000]      1
# 13692            [8/13/1994, 776736000000000]      1
# 13693            [7/18/1998, 900720000000000]      1
# 13694    [07/31/99-08/07/99, 933379200000000]      1
# 13695            [4/20/1996, 829958400000000]      1
# 13696          [11/27/2007, 1196121600000000]      1
# 13697           [4/12/2015, 1428796800000000]      1
# 13698          [12/19/1942, -853200000000000]      1
# 13699           [10/3/2001, 1002067200000000]      1
# 13700            [6/1/1963, -207878400000000]      1
# 13701           [5/23/1942, -871344000000000]      1
# 13702          [11/28/2001, 1006905600000000]      1
# 13703            [10/2/1989, 623289600000000]      1
# 13704               [6/3/91, 675907200000000]      1
# 13705           [7/14/1956, -425001600000000]      1
# 13706             [10/31/94, 783561600000000]      1
# 13707           [6/15/1957, -395971200000000]      1
# 13708          [10/30/1954, -478828800000000]      1
# 13709           [6/ 5/2008, 1212624000000000]      1
# 13710          [4/24/1934, -1126569600000000]      1
# 13711          [6/27/1942, -1215475200000000]      1
# 13712           [9/20/1947, -703209600000000]      1
# 13713             [3/1/1986, 510019200000000]      1
# 13714           [8/13/2013, 1376352000000000]      1
# 13715  [Jan2002 Supplement, 1012694400000000]      1
# 13716             [12/19/94, 787795200000000]      1
# 13717           [3/13/1965, -151632000000000]      1
# 13718           [11/2/2001, 1004659200000000]      1
#
# [13719 rows x 2 columns]

# %%
#Structured Date field analysis look for Ranges in the Structured date fields (Year, Month, Day)
print("Structured Date analysis starting")
mfsRecords_w_year = collection.count_documents({
    '$and' : [{ "header.content-type" :  "sch"},
    {"date.year" :  {"$exists" : True}}]
})
print("Percentage of MFS documents with a Year: ", mfsRecords_w_year/mfsRecords * 100)

imgRecords_w_year = collection.count_documents({
    '$and' : [{ "header.content-type" :  "imh"},
            {"date.year" :  {"$exists" : True}}]
})
print("Percentage of Image documents with a Year: ", imgRecords_w_year/imgRecords * 100)

ersRecords_w_year = collection.count_documents({
    '$and' : [{ "header.content-type" :  "ers"},
            {"date.year" :  {"$exists" : True}}]
})
print("Percentage of MFS documents with a Year: ", ersRecords_w_year/ersRecords * 100)
# Out:
# Structured Date analysis starting
# Percentage of MFS documents with a Year:  100.0
# Percentage of Image documents with a Year:  100.0
# Percentage of MFS documents with a Year:  100.0

# %%
print("Year Min / Max  analysis starting")
#year_max = collection.aggregate([
#    {"$match": {"date.date-type": "pub-date" }},
#    {"$group": {"_id:" : "year" , "ym" : {"$max" : "$date.year"}}}])

#year_max = collection.find({"date.year" : {"$exists" : True}}, sort=[("date.year", 1)])["date.year"]

year_max = collection.aggregate([
  { '$unwind': '$date' },
  { '$group': { '_id': 'null', 'max': { '$max': '$date.year' } } },
  { '$project': { 'max': 1, '_id':1 } }
]) 

print("Highest Year in the dataset: ",list(year_max)[0]['max'])

year_min = collection.aggregate([
  { '$unwind': '$date' },
  { '$group': { '_id': 'null', 'min': { '$min': '$date.year' } } },
  { '$project': { 'min': 1, '_id':1 } }
]) 

print("Lowest Year in the dataset: ",list(year_min)[0]['min'])

print("Year Min / Max  analysis complete")
# Out:
# Year Min / Max  analysis starting
# Highest Year in the dataset:  2022
# Lowest Year in the dataset:  1750
# Year Min / Max  analysis complete

# %%
#Content verticals distribution
print ("Content Vertical Analysis Starting")
Dist = collection.aggregate([{"$group" : 
                              {"_id" : {"vertical" : "$header.content-verticals"},
                               "total" : {"$sum" : 1} }},{"$sort": {"total": -1}}])
df = pd.DataFrame(list(Dist))
df["Perc"] = df['total'] / allRecords * 100
print ("Content Vertical Analysis complete")
# Out:
# Content Vertical Analysis Starting
# Content Vertical Analysis complete

# %%
df.round(2)
# Out:
#                                                   _id   total   Perc
# 0                         {'vertical': [['Article']]}  489054  42.26
# 1                           {'vertical': [['Image']]}  277109  23.95
# 2    {'vertical': [['Article', 'Scholarly Article']]}  128032  11.06
# 3                 {'vertical': [['Reference Entry']]}   69117   5.97
# 4      {'vertical': [['Reference Entry', 'Article']]}   35183   3.04
# 5                     {'vertical': [['Book Review']]}   22137   1.91
# 6           {'vertical': [['Book Review', 'Review']]}   21656   1.87
# 7               {'vertical': [['Letter', 'Article']]}   17716   1.53
# 8        {'vertical': [['Product Review', 'Review']]}   14607   1.26
# 9                          {'vertical': [['Letter']]}    7063   0.61
# 10                                 {'vertical': [[]]}    6752   0.58
# 11           {'vertical': [['Interview', 'Article']]}    6532   0.56
# 12           {'vertical': [['Editorial', 'Opinion']]}    5449   0.47
# 13                   {'vertical': [['Book Chapter']]}    4960   0.43
# 14                        {'vertical': [['Opinion']]}    3958   0.34
# 15          {'vertical': [['Proceeding', 'Article']]}    3443   0.30
# 16   {'vertical': [['Question & Answer', 'Article']]}    3407   0.29
# 17                      {'vertical': [['Editorial']]}    2666   0.23
# 18                {'vertical': [['Blog', 'Article']]}    2617   0.23
# 19  {'vertical': [['Letter to the Editor', 'Opinio...    2336   0.20
# 20                       {'vertical': [['Abstract']]}    2319   0.20
# 21              {'vertical': [['Correction notice']]}    2231   0.19
# 22                       {'vertical': [['Obituary']]}    2222   0.19
# 23  {'vertical': [['Entertainment Review', 'Review...    1836   0.16
# 24              {'vertical': [['Recipe', 'Article']]}    1809   0.16
# 25           {'vertical': [['Biography', 'Article']]}    1670   0.14
# 26            {'vertical': [['Chart/Diagram/Graph']]}    1454   0.13
# 27                      {'vertical': [['Interview']]}    1199   0.10
# 28             {'vertical': [['Excerpt', 'Article']]}    1165   0.10
# 29           {'vertical': [['Letter to the Editor']]}     958   0.08
# ..                                                ...     ...    ...
# 66                            {'vertical': [['Map']]}     112   0.01
# 67              {'vertical': [['Video Game Review']]}     110   0.01
# 68                      {'vertical': [['Cover Art']]}      86   0.01
# 69                      {'vertical': [['Biography']]}      78   0.01
# 70              {'vertical': [['Television Review']]}      78   0.01
# 71                  {'vertical': [['Course Review']]}      71   0.01
# 72                    {'vertical': [['Joke/Riddle']]}      65   0.01
# 73                {'vertical': [['Festival Review']]}      44   0.00
# 74              {'vertical': [['Report', 'Article']]}      42   0.00
# 75           {'vertical': [['Speech', 'Proceeding']]}      39   0.00
# 76                     {'vertical': [['Proceeding']]}      36   0.00
# 77             {'vertical': [['Performance Review']]}      35   0.00
# 78                    {'vertical': [['Script/Play']]}      33   0.00
# 79                        {'vertical': [['Project']]}      25   0.00
# 80                      {'vertical': [['Quotation']]}      25   0.00
# 81                   {'vertical': [['Music Review']]}      23   0.00
# 82              {'vertical': [['Industry Overview']]}      15   0.00
# 83               {'vertical': [['Art Reproduction']]}      14   0.00
# 84                  {'vertical': [['Poetry Review']]}       9   0.00
# 85                           {'vertical': [['Tale']]}       9   0.00
# 86                          {'vertical': [['Chart']]}       4   0.00
# 87      {'vertical': [['Film/Television Criticism']]}       3   0.00
# 88                           {'vertical': [['Book']]}       3   0.00
# 89                     {'vertical': [['Chronology']]}       3   0.00
# 90                 {'vertical': [['Company Report']]}       2   0.00
# 91             {'vertical': [['Short Story Review']]}       2   0.00
# 92                         {'vertical': [['Recipe']]}       1   0.00
# 93                        {'vertical': [['Diagram']]}       1   0.00
# 94                           {'vertical': [['Form']]}       1   0.00
# 95        {'vertical': [['Poetry Review', 'Review']]}       1   0.00
#
# [96 rows x 3 columns]

# %%
print ("AN Analysis Starting")
Dist = collection.find({"header.content-type" : "sch"},{"article-id-group.CreativeWork-id" : 1})
df = pd.DataFrame(list(Dist))
print ("AN Analysis complete")
# Out:
# AN Analysis Starting
# AN Analysis complete

# %%
df
# Out:
#                              _id                         article-id-group
# 0       5bb21e59588e1b919b1bb62e    [{'CreativeWork-id': '44278735'}, {}]
# 1       5bb21e59588e1b919b1bb62f  [{'CreativeWork-id': '9009170201'}, {}]
# 2       5bb21e59588e1b919b1bb630     [{'CreativeWork-id': '8932109'}, {}]
# 3       5bb21e59588e1b919b1bb631   [{'CreativeWork-id': '125639415'}, {}]
# 4       5bb21e59588e1b919b1bb632    [{'CreativeWork-id': '13863166'}, {}]
# 5       5bb21e59588e1b919b1bb633     [{'CreativeWork-id': '8802311'}, {}]
# 6       5bb21e59588e1b919b1bb634    [{'CreativeWork-id': '23696503'}, {}]
# 7       5bb21e59588e1b919b1bb635  [{'CreativeWork-id': '9604081156'}, {}]
# 8       5bb21e59588e1b919b1bb636        [{'CreativeWork-id': '5961'}, {}]
# 9       5bb21e59588e1b919b1bb638   [{'CreativeWork-id': '124773053'}, {}]
# 10      5bb21e59588e1b919b1bb639   [{'CreativeWork-id': '111725972'}, {}]
# 11      5bb21e59588e1b919b1bb63a  [{'CreativeWork-id': '9704274870'}, {}]
# 12      5bb21e59588e1b919b1bb63b    [{'CreativeWork-id': '12704728'}, {}]
# 13      5bb21e59588e1b919b1bb63d    [{'CreativeWork-id': '87402413'}, {}]
# 14      5bb21e59588e1b919b1bb63e     [{'CreativeWork-id': '8923714'}, {}]
# 15      5bb21e59588e1b919b1bb63f    [{'CreativeWork-id': '37704205'}, {}]
# 16      5bb21e59588e1b919b1bb640    [{'CreativeWork-id': '93983073'}, {}]
# 17      5bb21e59588e1b919b1bb641    [{'CreativeWork-id': '95942993'}, {}]
# 18      5bb21e59588e1b919b1bb642     [{'CreativeWork-id': '5553486'}, {}]
# 19      5bb21e59588e1b919b1bb643    [{'CreativeWork-id': '39253123'}, {}]
# 20      5bb21e59588e1b919b1bb644    [{'CreativeWork-id': '17543833'}, {}]
# 21      5bb21e59588e1b919b1bb645    [{'CreativeWork-id': '63006969'}, {}]
# 22      5bb21e59588e1b919b1bb646     [{'CreativeWork-id': '3549549'}, {}]
# 23      5bb21e59588e1b919b1bb648    [{'CreativeWork-id': '28690743'}, {}]
# 24      5bb21e59588e1b919b1bb649    [{'CreativeWork-id': '19790262'}, {}]
# 25      5bb21e59588e1b919b1bb64a  [{'CreativeWork-id': '9706243424'}, {}]
# 26      5bb21e59588e1b919b1bb64b    [{'CreativeWork-id': '20430157'}, {}]
# 27      5bb21e59588e1b919b1bb64d    [{'CreativeWork-id': '37360160'}, {}]
# 28      5bb21e59588e1b919b1bb64f    [{'CreativeWork-id': '34468136'}, {}]
# 29      5bb21e59588e1b919b1bb651   [{'CreativeWork-id': '110335947'}, {}]
# ...                          ...                                      ...
# 810906  5bd32753588e1b919ba1eacf   [{'CreativeWork-id': '132528962'}, {}]
# 810907  5bd32753588e1b919ba1eae3   [{'CreativeWork-id': '132528963'}, {}]
# 810908  5bd32754588e1b919ba1eb6e   [{'CreativeWork-id': '132528945'}, {}]
# 810909  5bd32754588e1b919ba1eb85   [{'CreativeWork-id': '132528966'}, {}]
# 810910  5bd32754588e1b919ba1eb92   [{'CreativeWork-id': '132528936'}, {}]
# 810911  5bd32754588e1b919ba1eb93   [{'CreativeWork-id': '132528947'}, {}]
# 810912  5bd32754588e1b919ba1ebad   [{'CreativeWork-id': '132528940'}, {}]
# 810913  5bd32754588e1b919ba1ebb7   [{'CreativeWork-id': '132528961'}, {}]
# 810914  5bd32754588e1b919ba1ebe1   [{'CreativeWork-id': '132528941'}, {}]
# 810915  5bd32755588e1b919ba1ec9d   [{'CreativeWork-id': '132538212'}, {}]
# 810916  5bd32755588e1b919ba1ecad   [{'CreativeWork-id': '132528935'}, {}]
# 810917  5bd32755588e1b919ba1ecb3   [{'CreativeWork-id': '132528950'}, {}]
# 810918  5bd32755588e1b919ba1ecb4   [{'CreativeWork-id': '132528986'}, {}]
# 810919  5bd32755588e1b919ba1ecc9   [{'CreativeWork-id': '132538216'}, {}]
# 810920  5bd32755588e1b919ba1ecca   [{'CreativeWork-id': '132528946'}, {}]
# 810921  5bd32755588e1b919ba1ed7c   [{'CreativeWork-id': '132528942'}, {}]
# 810922  5bd32755588e1b919ba1ed87   [{'CreativeWork-id': '132528955'}, {}]
# 810923  5bd32755588e1b919ba1ed88   [{'CreativeWork-id': '132528958'}, {}]
# 810924  5bd32755588e1b919ba1ed9c   [{'CreativeWork-id': '132528949'}, {}]
# 810925  5bd32755588e1b919ba1edad   [{'CreativeWork-id': '132538211'}, {}]
# 810926  5bd32755588e1b919ba1edb1   [{'CreativeWork-id': '132528983'}, {}]
# 810927  5bd32755588e1b919ba1edb4   [{'CreativeWork-id': '132528943'}, {}]
# 810928  5bd32756588e1b919ba1ee0b   [{'CreativeWork-id': '132528954'}, {}]
# 810929  5bd32756588e1b919ba1ee1f   [{'CreativeWork-id': '132528971'}, {}]
# 810930  5bd32756588e1b919ba1ee2e   [{'CreativeWork-id': '132528969'}, {}]
# 810931  5bd32756588e1b919ba1ee9c   [{'CreativeWork-id': '132528965'}, {}]
# 810932  5bd32756588e1b919ba1eea9   [{'CreativeWork-id': '132528938'}, {}]
# 810933  5bd32756588e1b919ba1eeaa   [{'CreativeWork-id': '132528959'}, {}]
# 810934  5bd32756588e1b919ba1eeaf   [{'CreativeWork-id': '132528964'}, {}]
# 810935  5bd32757588e1b919ba1eee4   [{'CreativeWork-id': '132528985'}, {}]
#
# [810936 rows x 2 columns]

# %%
ANMongo = []
for rec in df['article-id-group']:
    if ('CreativeWork-id' in rec[0]):
        ANMongo.append(rec[0]['CreativeWork-id'])
    #print(rec[0]['CreativeWork-id'])

# %%
import cx_Oracle

conn = cx_Oracle.connect('aws_reader/mfaws2@10.68.72.101:1521/mfaws2.epnet.com')
print (conn.version)
print ("AN Analysis Starting")
cursor = conn.cursor()
result = cursor.execute('SELECT AN FROM ARTICLE_SCH')
ANOracle = []

for record in result.fetchall():
    ANOracle.append(str(record[0]))

cursor.close()
conn.close()
print ("AN Analysis complete")
# Out:
# 10.2.0.3.0
# AN Analysis Starting
# AN Analysis complete

# %%
print("Count of Article number")
print("From Oracle " + str(len(ANOracle)))
print("From Mongo " + str(len(ANMongo)))
# Out:
# Count of Article number
# From Oracle 812456
# From Mongo 810936

# %%
differens=list(set(ANOracle) - set(ANMongo))
print("How many article numbers was matched: " + str(len(ANOracle) - len(differens)))
df = pd.DataFrame(differens)
# Out:
# How many article numbers was matched: 810936

# %%
df
# Out:
#                0
# 0         822340
# 1      130860113
# 2       19931958
# 3        3947879
# 4     9706043885
# 5       19931834
# 6      131505303
# 7        2535273
# 8      100095085
# 9       19932587
# 10      19931522
# 11     130651997
# 12        496302
# 13     131713745
# 14        822334
# 15      97077703
# 16      44203656
# 17       1975173
# 18      19932598
# 19       1852702
# 20      19932295
# 21      19931481
# 22     129723905
# 23      19931290
# 24     125631840
# 25     132542060
# 26        924020
# 27    9710012664
# 28    9709295349
# 29      19932755
# ...          ...
# 1490     3530064
# 1491       70175
# 1492      329875
# 1493    49789691
# 1494  9710064086
# 1495      329864
# 1496    19931874
# 1497   113260784
# 1498   130652293
# 1499  9711191727
# 1500   130025936
# 1501     3378948
# 1502   131959439
# 1503      329880
# 1504  9710114115
# 1505   125649953
# 1506    19930860
# 1507   125648190
# 1508    19931884
# 1509   125656407
# 1510    41994623
# 1511     1852717
# 1512   125654043
# 1513   125646323
# 1514    95867617
# 1515   125649362
# 1516   101822390
# 1517   101619288
# 1518    19931249
# 1519   102052048
#
# [1520 rows x 1 columns]

# %%
print("How many article numbers wasn't compare from Oracle: ", len(differens))
# Out:
# How many article numbers wasn't compare from Oracle:  1520

# %%
differensDoesNotExist=list(set(ANMongo) - set(ANOracle))

# %%
print("How many article numbers wasn't compare from Oracle to Mongo: ", len(differensDoesNotExist))
# Out:
# How many article numbers wasn't compare from Oracle to Mongo:  0

# %%
end = time.time()
print("Elapsed time in seconds: " + "{:.{}f}".format( (end - start), 2 ))
# Out:
# Elapsed time in seconds: 168.54

# %%
print("Job Completed at: "+str(datetime.datetime.now()))
# Out:
# Job Completed at: 2018-10-29 13:58:00.119652
